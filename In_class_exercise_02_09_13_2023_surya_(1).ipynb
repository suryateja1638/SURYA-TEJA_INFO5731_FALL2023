# %% [markdown]
# <a href="https://colab.research.google.com/github/suryateja1638/SURYA-TEJA_INFO5731_FALL2023/blob/main/In_class_exercise_02_09_13_2023_surya_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (09/13/2023, 40 points in total)

# %% [markdown]
# Kindly use the provided .ipynb document to write your code or respond to the questions. Avoid generating a new file.
# Execute all the cells before your final submission.

# %% [markdown]
# This in-class exercise is due tomorrow September 14, 2023 at 11:59 PM. No late submissions will be considered.

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question or something innovative) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %% [markdown]
# In current tech worls there are large varieaty of mobiles. But there is a huge demand in used mobiles. Now here we can collect data from webside of used mobiles and analyse based on there fearures. We can analyse mobile by its featres and predict the price. Here all the relevant adata of mobile is collected. This can be mobile name, varient, discounted price, actual price, warrenty. This data is analysed to get the value of the product. The data is collected from used mobile website. We use webscrapping libraries and take all relevant data which can be used for our analysis. The data is srored in dataframe for furthe analysis. Here we collect all data from website. we get almost 1100 data poits which could be good fpr modeling or analysis. The relevant libraries are imported. Different variables are intialized to store different features. The website is looped betwwn the pages to extract information in all pages. In each page the data is collected and appended in relevant variables. Then all variables with different features are combiled and made dataframe

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

import pandas as pd
import requests
from bs4 import BeautifulSoup as bs


name=[]
spec=[]
war=[]
dp = []
ap = []
for i in range (1,2):


    site='https://www.backmarket.com/en-us/l/smartphones/0744fd27-8605-465d-8691-3b6dffda5969?page='+ str(i) +'#'

    response = requests.get(site)

    soup = bs(response.content, 'html.parser')

    data = soup.find_all('div', {'class' : 'flex flex-col md:flex-1 md:justify-end'})


    for x in data:
        try:
            name.append(x.find('h2').get_text())
        except:
            name.append('na')

        try:
            spec.append(x.find('span', {'class':'body-2-light duration-200 line-clamp-1 normal-case overflow-ellipsis overflow-hidden text-black transition-all'}).get_text().strip())
        except:
            spec.append('na')
        try:
            war.append(x.find('span', {'class':'body-2-light text-black'}).get_text().strip())

        except:
            war.append('na')
        try:
            dp.append(x.find('span', {'class':'body-2-bold text-black'}).get_text().strip())
        except:
            dp.append('na')
        try:
            ap.append(x.find('div', {'class':'body-2-light text-primary-light line-through'}).get_text().strip())
        except:
            ap.append('na')
df = pd.DataFrame({'Name': name, 'type':spec, 'Discounted price':dp,
                                'Actual Price': ap,'Warrenty': war})
df
# Out:
#                                                  Name      type  \
# 0      \n          Galaxy S21 5G - Unlocked\n          Unlocked
# 1          \n          iPhone 11 - Unlocked\n          Unlocked
# 2   \n          iPhone 12 Pro Max - Unlocked\n    ...  Unlocked
# 3          \n          iPhone 12 - Unlocked\n          Unlocked
# 4      \n          iPhone 12 Pro - Unlocked\n          Unlocked
# 5          \n          iPhone XR - Unlocked\n          Unlocked
# 6   \n          Galaxy S20 FE 5G - Unlocked\n          Unlocked
# 7          \n          iPhone 13 - Unlocked\n          Unlocked
# 8   \n          Galaxy S21 Ultra 5G - Unlocked\n  ...  Unlocked
# 9           \n          iPhone 8 - Unlocked\n          Unlocked
# 10       \n          Galaxy S10e - Unlocked\n          Unlocked
# 11    \n          iPhone 12 mini - Unlocked\n          Unlocked
# 12        \n          Galaxy S10 - Unlocked\n          Unlocked
# 13    \n          Google Pixel 5 - Unlocked\n          Unlocked
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2013-2023).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
# You code here (Please add comments in the code):
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Function to collect article data
def collect_articles(query, num_articles):
    base_url = "https://scholar.google.com/scholar"
    collected_articles = []

    while len(collected_articles) < num_articles:
        params = {
            "q": query,
            "hl": "en",
            "start": len(collected_articles),
        }

        response = requests.get(base_url, params=params)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find article entries
        entries = soup.find_all("div", class_="gs_ri")

        for entry in entries:
            article_data = {}

            # Title
            title = entry.find("h3", class_="gs_rt")
            article_data["Title"] = title.text if title else "N/A"

            # Venue or Journal
            venue = entry.find("div", class_="gs_a")
            article_data["Venue"] = venue.text if venue else "N/A"

            # Year
            year = entry.find("div", class_="gs_a").text.split(" - ")[-1]
            article_data["Year"] = year if year else "N/A"

            # Authors
            authors = entry.find("div", class_="gs_a").text.split(" - ")[0]
            article_data["Authors"] = authors if authors else "N/A"

            # Abstract (if available)
            abstract = entry.find("div", class_="gs_rs")
            article_data["Abstract"] = abstract.text if abstract else "N/A"

            collected_articles.append(article_data)

    return collected_articles

# Specify the query and number of articles to collect
query = "Data Science"
num_articles = 1000

# Collect articles
articles = collect_articles(query, num_articles)


for i, article in enumerate(articles, start=1):
    print(f"Article {i}:")
    print(f"Title: {article['Title']}")
    print(f"Venue/Journal: {article['Venue']}")
    print(f"Year: {article['Year']}")
    print(f"Authors: {article['Authors']}")
    print(f"Abstract: {article['Abstract']}")
    print("\n")
# Out:
# Article 1:
# Title: Data science and prediction
# Venue/Journal: V Dhar - Communications of the ACM, 2013 - dl.acm.org
# Year: dl.acm.org
# Authors: V Dhar - Communications of the ACM, 2013
# Abstract: … Data science might therefore imply a focus involving data and, by extension, statistics, or
# the systematic study of the organization, properties, and analysis of data and its role in …
#
#
# Article 2:
# Title: [BOOK][B] R for data science
# Venue/Journal: H Wickham, M Çetinkaya-Rundel, G Grolemund - 2023 - books.google.com
# Year: books.google.com
# Authors: H Wickham, M Çetinkaya-Rundel, G Grolemund
# Abstract: … In our model of the data science process, you start with data import and tidying. Next, you
# understand your data with an iterative cycle of transforming, visualizing, and modeling. You …
#
#
# Article 3:
# Title: [BOOK][B] Data science in action
# Venue/Journal: W Van Der Aalst, W van der Aalst - 2016 - Springer
# Year: Springer
# ...

# %% [markdown]
# Do either of the question-4 tasks given below.

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
import instaloader
import pandas as pd
# Initialize an Instaloader instance
L = instaloader.Instaloader()

 #Login to your Instagram account (if needed)
 #L.login('your_username', 'your_password')

# Replace 'instagram_user' with the username you want to collect posts from
profile = instaloader.Profile.from_username(L.context, 'deepthi_sunaina')

# Create a list to store the collected data
collected_data = []

# Specify the number of posts you want to collect (e.g., 1000)
num_posts_to_collect = 1100

# Iterate through the user's posts and collect data
for post in profile.get_posts():
    if len(collected_data) >= num_posts_to_collect:
        break  # Stop collecting after reaching the desired number of posts

    user_name = post.owner_username
    posted_time = post.date_utc
    text = post.caption

    # Append the data to the list
    collected_data.append({
        'User_name': user_name,
        'Posted_time': posted_time,
        'Text': text,
    })

# Create a DataFrame from the collected data
df = pd.DataFrame(collected_data)

# Print the DataFrame
df
# Out:
# C:\Users\gonug\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# C:\Users\gonug\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\gonug\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\gonug\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
#             User_name         Posted_time  \
# 0     deepthi_sunaina 2023-09-16 06:06:14
# 1     deepthi_sunaina 2023-08-01 11:59:55
# 2     deepthi_sunaina 2023-09-17 06:11:09
# 3     deepthi_sunaina 2023-09-06 13:35:01
# 4     deepthi_sunaina 2023-08-25 13:12:54
# ...               ...                 ...
# ...

# %%
pip install instaloader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for instaloader: filename=instaloader-4.10-py3-none-any.whl size=64278 sha256=192575a4c20f8d7d72bc02f1f66bd31bdebb686472396441fd895706ee3a563a
#   Stored in directory: /root/.cache/pip/wheels/5b/8d/e0/866c1ad8efef4ab789acf51c4b317711d63f62af0228a6a676
# Successfully built instaloader
# ...

# %% [markdown]
# Question 4 (10 points):
#
# In this task, you are required to identify and utilize online tools for web scraping data from websites without the need for coding, with a specific focus on Parsehub. The objective is to gather data and save it in formats like CSV, Excel, or any other suitable file format.
#
# You have to mention an introduction to the tool which ever you prefer to use, steps to follow for web scrapping and the final output of the data collected.
#
# Upload a document (Word or PDF File) in the same repository and you can add the link in the ipynb file.

# %%
# Upload the link to the document here
